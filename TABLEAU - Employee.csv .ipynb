# %% [markdown]
# ## Here’s how to structure "Employee.csv" visualizations in Tableau

# %% [markdown]
# ### Number of Employees by City
#  *Create a bar chart.
#  *Drag City to the Columns shelf.
#  *Drag NumberOfEmployees to the Rows shelf.

# %% [markdown]
# ![image.png](attachment:5019c8d2-d6f3-4702-b9c3-b2e0730a959b.png)

# %% [markdown]
# ### Average Age of Employees in Each Payment Tier
# o	Create a bar chart.
# o	Drag PaymentTier to the Columns shelf change the aggregation to dimention.
# o	Drag Age to the Rows shelf and change the aggregation to AVG.

# %% [markdown]
# ![image.png](attachment:77a1f316-f8ed-4f10-93d8-23ff19bf9e37.png)

# %% [markdown]
# ### Number of Employees by Gender and City
# o	Create a stacked bar chart.
# o	Drag City to the Columns shelf.
# o	Drag Gender to the Color shelf.
# o	Drag NumberOfEmployees to the Rows shelf.

# %% [markdown]
# ![image.png](attachment:757833f6-745e-4b7b-8b52-897164b8bc19.png)

# %% [markdown]
# ### Distribution of Education Levels:
# o	Create a pie chart.
# o	Drag Education to the Color shelf.
# o	Drag NumberOfEmployees to the Angle shelf.

# %% [markdown]
# ![image.png](attachment:92066807-4b2e-464c-96e9-87df290748f8.png)

# %% [markdown]
# ### Percentage of Employees Who Have Left
#                     •  Create a calculated field for the percentage.
# •  Use the formula: (COUNT(IF [LeaveOrNot] = 1 THEN 1 END) / COUNT([LeaveOrNot])) * 100
#                     •  Drag this calculated field to the Text shelf.

# %% [markdown]
# ![image.png](attachment:83b8d964-c5e5-49ad-83f3-60e915552711.png)

# %% [markdown]
# ### Maximum and Minimum Age of Employees in Each City
# o	Drag City to the Columns shelf.
# o	Drag Age to the Columns shelf and change aggregation to dimention.
# o	Drag Age to the Rows shelf twice, set one to MAX and the other to MIN.

# %% [markdown]
# ![image.png](attachment:ff6b27d9-9b63-48ee-bf71-9ed60f8ce27c.png)

# %% [markdown]
# ### Average Age of Employees by Education Level
# o	Create a bar chart.
# o	Drag Education to the Columns shelf.
# o	Drag Age to the Rows shelf and change the aggregation to AVG.

# %% [markdown]
# ![image.png](attachment:1b2638d7-fa3e-4b32-93b3-4da33ff464ff.png)

# %% [markdown]
# ### Number of Employees Who Joined Each Year
# o	Create a line chart.
# o	Drag JoiningYear to the Columns shelf.
# o	Drag NumberOfEmployees to the Rows shelf.

# %% [markdown]
# ![image.png](attachment:46b4c56f-46ce-4dcf-89f3-63556145b935.png)

# %% [markdown]
# ### Number of Employees in Each Payment Tier by Education Level
# o	Create a stacked bar chart.
# o	Drag Education to the Columns shelf.
# o	Drag PaymentTier to the Color shelf.
# o	Drag NumberOfEmployees to the Rows shelf.

# %% [markdown]
# ![image.png](attachment:490d5da8-6efa-4d24-b125-bd40cdd3afcf.png)

# %% [markdown]
# ## Combine Visualizations into a Dashboard Go to the Dashboard tab. Drag and drop the individual sheets created above into the dashboard. Arrange them in a logical layout that makes it easy to compare different metrics.

# %% [markdown]
# ![image.png](attachment:9f5f14c5-fc4d-486b-883d-3934412512c2.png)
